# %%
import pandas as pd

from openpyxl import load_workbook
from openpyxl.styles import NamedStyle, PatternFill, Font, numbers
from openpyxl.worksheet.table import Table, TableStyleInfo

# %%
df = pd.read_excel(r'C:\Users\Thomas\Downloads\Base_v2\Renovacao\Dados_Renovacao\Agrupado\Renovacoes_agrupado.xlsx')

# %%
pivot_df = df.pivot_table(index='Inspetor de producao', columns='Ramo Seguro', aggfunc='size', fill_value=0)

# %%
colunas_piv = ['Auto', 'Residencial sob medida', 'Equipamento', 'Equipamento agrícola', 'Empresarial', 'Frota']
colunas_piv_existe = pivot_df.columns.tolist()
sequencia_c = [elemento for elemento in colunas_piv if elemento in colunas_piv_existe] #deixa a lista na sequencia certa
pivot_df = pivot_df[sequencia_c]

# %%
def export_to_excel_with_format(df, file_path):

# Exporta o DataFrame para um arquivo Excel
    df.to_excel(file_path, index=True)

    # Carrega o arquivo Excel
    wb = load_workbook(file_path)
    ws = wb.active



    # Cria um estilo para o cabeçalho
    header_style = NamedStyle(name='header')
    header_style.fill = PatternFill(start_color='FF0000', end_color='FF0000', fill_type='solid')
    header_style.font = Font(color='FFFFFF', bold=True)  # Título em negrito



    # Aplica a formatação ao cabeçalho de todas as colunas
    for col_idx in range(1, len(df.columns) + 2):
        ws.cell(row=1, column=col_idx).style = header_style

    # Ajusta a largura das colunas automaticamente
    for col_idx, column in enumerate(ws.columns, start=1):
        max_length = 0
        column_letter = ws.cell(row=1, column=col_idx).column_letter
        for cell in column:
            try:
                if cell.value is not None:
                    cell_length = len(str(cell.value))
                    if cell_length > max_length:
                        max_length = cell_length
            except:
                pass
        adjusted_width = max_length + 2  # Adiciona um pequeno espaço extra
        ws.column_dimensions[column_letter].width = max(10, adjusted_width)  # Largura mínima de 10

    # Adiciona um filtro à planilha
    ws.auto_filter.ref = ws.dimensions  # Define o autofiltro para todas as células preenchidas

    # Salva o arquivo Excel com a formatação aplicada
    wb.save(file_path)

# %%
export_to_excel_with_format(pivot_df,r'C:\Users\Thomas\Downloads\Base_v2\Renovacao\Dados_Renovacao\Agrupado\AgostoRen.xlsx')

# %%
import pandas as pd

# Definindo o caminho do arquivo
file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado.xlsx'

# Lendo a planilha
df = pd.read_excel(file_path)

# Exibindo as primeiras linhas do DataFrame para verificar a leitura
print("Dados originais:")
print(df.head())

# Função para converter a data para o formato desejado
def convert_date_format(date_str):
    return pd.to_datetime(date_str, format='%d/%m/%Y').strftime('%Y-%m-%d')

# Alterando o formato das colunas de data
date_columns = ['Data de Emissao', 'Inicio Vigencia', 'Fim Vigencia']
for col in date_columns:
    df[col] = df[col].apply(convert_date_format)

# Exibindo as primeiras linhas do DataFrame após a conversão
print("Dados após a conversão:")
print(df.head())

# Salvando o DataFrame modificado em um novo arquivo Excel
output_file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado_modificado.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Arquivo salvo em: {output_file_path}")
# Out:
# Dados originais:
#    Unnamed: 0    Cia   Ramo  CPD Corretor                         Corretor  \
# 0           0  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 1           1  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 2           2  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 3           3  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 4           4  531.0  990.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
#
#     Apolice  Item  Endosso                         Segurado  N Contrato  ...  \
# 0   14829.0   1.0      0.0  ROZANA APARECIDA GOMES PINHEIRO         0.0  ...
# 1   17689.0   1.0      0.0       BENEDITO DOMINGOS DE PAULA         0.0  ...
# 2   17773.0   1.0      0.0            EDUARDA SILVA RIBEIRO         0.0  ...
# 3   17868.0   1.0      0.0     GLEISON WALDIR BRASIL JUNIOR         0.0  ...
# 4  109572.0   1.0      0.0     ANDERSON OLIVEIRA DOS SANTOS         0.0  ...
#
# ...

# %%
import pandas as pd

# Definindo o caminho do arquivo
file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado.xlsx'

# Lendo a planilha
df = pd.read_excel(file_path)

# Exibindo as primeiras linhas do DataFrame para verificar a leitura
print("Dados originais:")
print(df.head())

# Função para converter a data para o formato desejado
def convert_date_format(date_str):
    # Tenta converter a string da data
    try:
        return pd.to_datetime(date_str, format='%d-%m-%Y').strftime('%Y-%m-%d')
    except ValueError:
        return date_str  # Retorna a string original se falhar na conversão

# Alterando o formato das colunas de data
date_columns = ['Data de Emissao', 'Inicio Vigencia', 'Fim Vigencia']
for col in date_columns:
    df[col] = df[col].apply(convert_date_format)

# Exibindo as primeiras linhas do DataFrame após a conversão
print("Dados após a conversão:")
print(df.head())

# Salvando o DataFrame modificado em um novo arquivo Excel
output_file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado_modificado.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Arquivo salvo em: {output_file_path}")

# %%
import pandas as pd

# Definindo o caminho do arquivo
file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado.xlsx'

# Lendo a planilha
df = pd.read_excel(file_path)

# Exibindo as primeiras linhas do DataFrame para verificar a leitura
print("Dados originais:")
print(df.head())

# Função para converter a data para o formato desejado
def convert_date_format(date_str):
    # Tenta converter a string da data
    try:
        return pd.to_datetime(date_str, format='%d-%m-%Y').strftime('%Y-%m-%d')
    except ValueError:
        return date_str  # Retorna a string original se falhar na conversão

# Alterando o formato das colunas de data
date_columns = ['Data de Emissao', 'Inicio Vigencia', 'Fim Vigencia']
for col in date_columns:
    df[col] = df[col].apply(convert_date_format)

# Removendo símbolos de moeda das colunas de valor
currency_columns = ['Valor Premio Liquido', 'Valor Premio Total']
for col in currency_columns:
    df[col] = df[col].str.replace('$', '', regex=False)  # Remove o símbolo $
    df[col] = df[col].str.replace('R$', '', regex=False)  # Remove o símbolo R$

    # Converte as colunas para o tipo float, caso necessário
    df[col] = df[col].str.replace(',', '.').astype(float)

# Exibindo as primeiras linhas do DataFrame após as modificações
print("Dados após a conversão e remoção de símbolos:")
print(df.head())

# Salvando o DataFrame modificado em um novo arquivo Excel
output_file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado_modificado.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Arquivo salvo em: {output_file_path}")
# Out:
# Dados originais:
#    Unnamed: 0    Cia   Ramo  CPD Corretor                         Corretor  \
# 0           0  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 1           1  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 2           2  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 3           3  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 4           4  531.0  990.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
#
#     Apolice  Item  Endosso                         Segurado  N Contrato  ...  \
# 0   14829.0   1.0      0.0  ROZANA APARECIDA GOMES PINHEIRO         0.0  ...
# 1   17689.0   1.0      0.0       BENEDITO DOMINGOS DE PAULA         0.0  ...
# 2   17773.0   1.0      0.0            EDUARDA SILVA RIBEIRO         0.0  ...
# 3   17868.0   1.0      0.0     GLEISON WALDIR BRASIL JUNIOR         0.0  ...
# 4  109572.0   1.0      0.0     ANDERSON OLIVEIRA DOS SANTOS         0.0  ...
#
# ...

# %%
import pandas as pd

# Definindo o caminho do arquivo
file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado.xlsx'

# Lendo a planilha
df = pd.read_excel(file_path)

# Exibindo as primeiras linhas do DataFrame para verificar a leitura
print("Dados originais:")
print(df.head())

# Função para converter a data para o formato desejado
def convert_date_format(date_str):
    # Tenta converter a string da data
    try:
        return pd.to_datetime(date_str, format='%d-%m-%Y').strftime('%Y-%m-%d')
    except ValueError:
        return date_str  # Retorna a string original se falhar na conversão

# Alterando o formato das colunas de data
date_columns = ['Data de Emissao', 'Inicio Vigencia', 'Fim Vigencia']
for col in date_columns:
    df[col] = df[col].apply(convert_date_format)

# Removendo símbolos de moeda e ajustando os valores
currency_columns = ['Valor Premio Liquido', 'Valor Premio Total']
for col in currency_columns:
    df[col] = df[col].str.replace('$', '', regex=False)  # Remove o símbolo $
    df[col] = df[col].str.replace('R$', '', regex=False)  # Remove o símbolo R$
    
    # Remove separadores de milhar (pontos) e substitui a vírgula por ponto decimal
    df[col] = df[col].str.replace('.', '', regex=False)  # Remove o ponto de milhar
    df[col] = df[col].str.replace(',', '.', regex=False)  # Substitui vírgula por ponto

    # Converte as colunas para o tipo float
    df[col] = df[col].astype(float)

# Exibindo as primeiras linhas do DataFrame após as modificações
print("Dados após a conversão e remoção de símbolos:")
print(df.head())

# Salvando o DataFrame modificado em um novo arquivo Excel
output_file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado_modificado.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Arquivo salvo em: {output_file_path}")
# Out:
# Dados originais:
#    Unnamed: 0    Cia   Ramo  CPD Corretor                         Corretor  \
# 0           0  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 1           1  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 2           2  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 3           3  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 4           4  531.0  990.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
#
#     Apolice  Item  Endosso                         Segurado  N Contrato  ...  \
# 0   14829.0   1.0      0.0  ROZANA APARECIDA GOMES PINHEIRO         0.0  ...
# 1   17689.0   1.0      0.0       BENEDITO DOMINGOS DE PAULA         0.0  ...
# 2   17773.0   1.0      0.0            EDUARDA SILVA RIBEIRO         0.0  ...
# 3   17868.0   1.0      0.0     GLEISON WALDIR BRASIL JUNIOR         0.0  ...
# 4  109572.0   1.0      0.0     ANDERSON OLIVEIRA DOS SANTOS         0.0  ...
#
# ...

# %%
import pandas as pd

# Definindo o caminho do arquivo
file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado.xlsx'

# Lendo a planilha
df = pd.read_excel(file_path)

# Exibindo as primeiras linhas do DataFrame para verificar a leitura
print("Dados originais:")
print(df.head())

# Função para converter a data para o formato desejado
def convert_date_format(date_str):
    # Tenta converter a string da data
    try:
        return pd.to_datetime(date_str, format='%d-%m-%Y').strftime('%Y-%m-%d')
    except ValueError:
        return date_str  # Retorna a string original se falhar na conversão

# Alterando o formato das colunas de data
date_columns = ['Data de Emissao', 'Inicio Vigencia', 'Fim Vigencia']
for col in date_columns:
    df[col] = df[col].apply(convert_date_format)

# Removendo símbolos de moeda e ajustando os valores
currency_columns = ['Valor Premio Liquido', 'Valor Premio Total']
for col in currency_columns:
    df[col] = df[col].str.replace('$', '', regex=False)  # Remove o símbolo $
    df[col] = df[col].str.replace('R$', '', regex=False)  # Remove o símbolo R$
    
    # Remove separadores de milhar (vírgula) e substitui o ponto por vírgula decimal
    df[col] = df[col].str.replace('.', '', regex=False)  # Remove o ponto de milhar
    df[col] = df[col].str.replace(',', '.', regex=False)  # Substitui vírgula por ponto

    # Converte as colunas para o tipo float
    df[col] = df[col].astype(float)

# Exibindo as primeiras linhas do DataFrame após as modificações
print("Dados após a conversão e remoção de símbolos:")
print(df.head())

# Salvando o DataFrame modificado em um novo arquivo Excel
output_file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado_modificado.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Arquivo salvo em: {output_file_path}")
# Out:
# Dados originais:
#    Unnamed: 0    Cia   Ramo  CPD Corretor                         Corretor  \
# 0           0  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 1           1  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 2           2  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 3           3  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 4           4  531.0  990.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
#
#     Apolice  Item  Endosso                         Segurado  N Contrato  ...  \
# 0   14829.0   1.0      0.0  ROZANA APARECIDA GOMES PINHEIRO         0.0  ...
# 1   17689.0   1.0      0.0       BENEDITO DOMINGOS DE PAULA         0.0  ...
# 2   17773.0   1.0      0.0            EDUARDA SILVA RIBEIRO         0.0  ...
# 3   17868.0   1.0      0.0     GLEISON WALDIR BRASIL JUNIOR         0.0  ...
# 4  109572.0   1.0      0.0     ANDERSON OLIVEIRA DOS SANTOS         0.0  ...
#
# ...

# %%
import pandas as pd

# Definindo o caminho do arquivo
file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado.xlsx'

# Lendo a planilha
df = pd.read_excel(file_path)

# Exibindo as primeiras linhas do DataFrame para verificar a leitura
print("Dados originais:")
print(df.head())

# Função para converter a data para o formato desejado
def convert_date_format(date_str):
    # Tenta converter a string da data
    try:
        return pd.to_datetime(date_str, format='%d-%m-%Y').strftime('%Y-%m-%d')
    except ValueError:
        return date_str  # Retorna a string original se falhar na conversão

# Alterando o formato das colunas de data
date_columns = ['Data de Emissao', 'Inicio Vigencia', 'Fim Vigencia']
for col in date_columns:
    df[col] = df[col].apply(convert_date_format)

# Removendo símbolos de moeda e ajustando os valores
currency_columns = ['Valor Premio Liquido', 'Valor Premio Total']
for col in currency_columns:
    df[col] = df[col].str.replace('$', '', regex=False)  # Remove o símbolo $
    df[col] = df[col].str.replace('R$', '', regex=False)  # Remove o símbolo R$
    
    # Remove a vírgula (separador de milhar) e mantém o ponto como separador decimal
    df[col] = df[col].str.replace(',', '', regex=False)  # Remove a vírgula de milhar

    # Converte as colunas para o tipo float, mantendo o ponto como separador decimal
    df[col] = df[col].astype(float)

# Exibindo as primeiras linhas do DataFrame após as modificações
print("Dados após a conversão e remoção de símbolos:")
print(df.head())

# Salvando o DataFrame modificado em um novo arquivo Excel
output_file_path = r'C:\Users\Thomas\Downloads\Base_v2\Emissao\Dados_Emissao\Agrupado\Emissoes_agrupado_modificado.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Arquivo salvo em: {output_file_path}")
# Out:
# Dados originais:
#    Unnamed: 0    Cia   Ramo  CPD Corretor                         Corretor  \
# 0           0  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 1           1  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 2           2  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 3           3  531.0  927.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
# 4           4  531.0  990.0        505404  A L CORR DE SEGS SOC UNIPESSOAL
#
#     Apolice  Item  Endosso                         Segurado  N Contrato  ...  \
# 0   14829.0   1.0      0.0  ROZANA APARECIDA GOMES PINHEIRO         0.0  ...
# 1   17689.0   1.0      0.0       BENEDITO DOMINGOS DE PAULA         0.0  ...
# 2   17773.0   1.0      0.0            EDUARDA SILVA RIBEIRO         0.0  ...
# 3   17868.0   1.0      0.0     GLEISON WALDIR BRASIL JUNIOR         0.0  ...
# 4  109572.0   1.0      0.0     ANDERSON OLIVEIRA DOS SANTOS         0.0  ...
#
# ...
